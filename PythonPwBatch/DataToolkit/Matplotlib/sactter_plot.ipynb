# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.13090408, 0.30424091, 0.3617837 , 0.61940671, 0.04925794,
#        0.40398935, 0.73935153, 0.8382796 , 0.5808217 , 0.79132918,
#        0.29531375, 0.39598617, 0.25237029, 0.46248971, 0.7183128 ,
#        0.57692777, 0.83457315, 0.05417245, 0.65151348, 0.27264053,
#        0.23689546, 0.47193036, 0.3102453 , 0.71199582, 0.42569967,
#        0.22583622, 0.04731536, 0.47149041, 0.71108022, 0.87504563,
#        0.5846219 , 0.77456436, 0.51944674, 0.16089365, 0.80366795,
#        0.80847148, 0.42707769, 0.03591432, 0.97368835, 0.50379789,
#        0.92204178, 0.0203948 , 0.96642609, 0.68149383, 0.22985829,
#        0.89352534, 0.82307599, 0.73399042, 0.89752553, 0.65709295])

# %%
y
# Out:
# array([0.76659731, 0.6378196 , 0.19626629, 0.53633341, 0.40002868,
#        0.22114694, 0.95922217, 0.74242301, 0.44593505, 0.71932924,
#        0.50118563, 0.11877279, 0.43483394, 0.36100538, 0.99896671,
#        0.04206491, 0.515785  , 0.95370181, 0.16219075, 0.4106725 ,
#        0.1868269 , 0.4480487 , 0.66416668, 0.91777831, 0.53974901,
#        0.08668908, 0.34311653, 0.24283947, 0.24579561, 0.05875067,
#        0.47391562, 0.97683571, 0.67754858, 0.14297503, 0.38629885,
#        0.16368581, 0.35418719, 0.81137095, 0.09168286, 0.67918361,
#        0.05452682, 0.5399439 , 0.17409614, 0.14189101, 0.31906736,
#        0.18121056, 0.24019656, 0.50674737, 0.47475966, 0.94865172])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, color='red')
plt.show()

# %%
plt.scatter(x,y, color='red', marker='x')
plt.show()

# %%
plt.scatter(x,y, color='red', marker='o')
plt.show()
