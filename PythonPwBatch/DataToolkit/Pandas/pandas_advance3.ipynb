# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S

# %%
df1 = df[["Name","Sex","Age"]][0:5]

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 = df[["Name","Sex","Age"]][5:10]

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
#dataframe concatenation 
#1 horizontal
#2 vertical

# %%
pd.concat([df1,df2], axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
pd.concat([df1,df2], axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
import pandas as pd
df1 = pd.DataFrame(
    {
        'key1':[1,2,4,5,6],
        'key2':[4,5,6,7,8],
        'key3':[3,4,5,6,6]
    }
)

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2 = pd.DataFrame(
    {
        'key1':[1,2,45,6,67],
        'key4':[56,5,6,7,8],
        'key5':[3,56,5,6,6]
    }
)

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2, how='inner')   #if same column
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
df1, df2
# Out:
# (   key1  key2  key3
#  0     1     4     3
#  1     2     5     4
#  2     4     6     5
#  3     5     7     6
#  4     6     8     6,
#     key1  key4  key5
#  0     1    56     3
#  1     2     5    56
#  2    45     6     5
#  3     6     7     6
#  4    67     8     6)

# %%
pd.merge(df1, df2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  0     1     4     3
#  1     2     5     4
#  2     4     6     5
#  3     5     7     6
#  4     6     8     6,
#     key1  key4  key5
#  0     1    56     3
#  1     2     5    56
#  2    45     6     5
#  3     6     7     6
#  4    67     8     6)

# %%
pd.merge(df1, df2, how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  0     1     4     3
#  1     2     5     4
#  2     4     6     5
#  3     5     7     6
#  4     6     8     6,
#     key1  key4  key5
#  0     1    56     3
#  1     2     5    56
#  2    45     6     5
#  3     6     7     6
#  4    67     8     6)

# %%
pd.merge(df1, df2, how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  0     1     4     3
#  1     2     5     4
#  2     4     6     5
#  3     5     7     6
#  4     6     8     6,
#     key1  key4  key5
#  0     1    56     3
#  1     2     5    56
#  2    45     6     5
#  3     6     7     6
#  4    67     8     6)

# %%
pd.merge(df1,df2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
#join

# %%
df1 = pd.DataFrame(
    {
        'key1':[1,2,4,5,6],
        'key2':[4,5,6,7,8],
        'key3':[3,4,5,6,6],
    }
    ,index = ['a','b','c','d','e']

)

# %%
df2 = pd.DataFrame(
    {
        'key6':[1,2,45,6,67],
        'key4':[56,5,6,7,8],
        'key5':[3,56,5,6,6]
    },
    index=['a','b','h','i','j']
)

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  a     1     4     3
#  b     2     5     4
#  c     4     6     5
#  d     5     7     6
#  e     6     8     6,
#     key6  key4  key5
#  a     1    56     3
#  b     2     5    56
#  h    45     6     5
#  i     6     7     6
#  j    67     8     6)

# %%
df1.join(df2, how='inner')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df2.join(df1, how='inner')
# Out:
#    key6  key4  key5  key1  key2  key3
# a     1    56     3     1     4     3
# b     2     5    56     2     5     4

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  a     1     4     3
#  b     2     5     4
#  c     4     6     5
#  d     5     7     6
#  e     6     8     6,
#     key6  key4  key5
#  a     1    56     3
#  b     2     5    56
#  h    45     6     5
#  i     6     7     6
#  j    67     8     6)

# %%
df1.join(df2, how='left')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df1.join(df2, how='outer')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  a     1     4     3
#  b     2     5     4
#  c     4     6     5
#  d     5     7     6
#  e     6     8     6,
#     key6  key4  key5
#  a     1    56     3
#  b     2     5    56
#  h    45     6     5
#  i     6     7     6
#  j    67     8     6)

# %%
df2.join(df1, how='outer')
# Out:
#    key6  key4  key5  key1  key2  key3
# a   1.0  56.0   3.0   1.0   4.0   3.0
# b   2.0   5.0  56.0   2.0   5.0   4.0
# c   NaN   NaN   NaN   4.0   6.0   5.0
# d   NaN   NaN   NaN   5.0   7.0   6.0
# e   NaN   NaN   NaN   6.0   8.0   6.0
# h  45.0   6.0   5.0   NaN   NaN   NaN
# i   6.0   7.0   6.0   NaN   NaN   NaN
# j  67.0   8.0   6.0   NaN   NaN   NaN

# %%
df1,df2
# Out:
# (   key1  key2  key3
#  a     1     4     3
#  b     2     5     4
#  c     4     6     5
#  d     5     7     6
#  e     6     8     6,
#     key6  key4  key5
#  a     1    56     3
#  b     2     5    56
#  h    45     6     5
#  i     6     7     6
#  j    67     8     6)

# %%
df1.join(df2, how='cross')
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      1     4     3     1    56     3
# 1      1     4     3     2     5    56
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1    56     3
# 6      2     5     4     2     5    56
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1    56     3
# 11     4     6     5     2     5    56
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1    56     3
# 16     5     7     6     2     5    56
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1    56     3
# 21     6     8     6     2     5    56
# 22     6     8     6    45     6     5
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df['new_fare'] = df['Fare'].apply(lambda x: x*90)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def convert_fare(x):
    return x*90

# %%
df['fare1'] = df.Fare.apply(convert_fare)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def check_fare(x):
    if x<=10:
        return "cheap"
    elif x>10 and x<=30:
        return "medium"
    else:
        return "high"

# %%
df['fare_info'] = df.Fare.apply(check_fare)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data =  {
    'a':[1,2,3,4],
    'b':[5,5,6,7],
    'c':['pw','skills','aj','cj']
              }

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    a  b       c
# 0  1  5      pw
# 1  2  5  skills
# 2  3  6      aj
# 3  4  7      cj

# %%
df1.set_index('c', inplace=True)

# %%
df1
# Out:
#         a  b
# c
# pw      1  5
# skills  2  5
# aj      3  6
# cj      4  7

# %%
df1['a']
# Out:
# c
# pw        1
# skills    2
# aj        3
# cj        4
# Name: a, dtype: int64

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.reindex([0,0,3,3,1])
# Out:
#    a  b
# 0  1  5
# 0  1  5
# 3  4  7
# 3  4  7
# 1  2  5

# %%
df1 = df1.reindex([1,2,1,0])

# %%
df1
# Out:
#    a  b
# 1  2  5
# 2  3  6
# 1  2  5
# 0  1  5

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
#iteration on the dataframe

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
# row wise iteration
for i in df1.iterrows():
    print(i)
    print('__________________')
# Out:
# (0, a    2
# b    5
# Name: 0, dtype: int64)
# __________________
# (1, a    3
# b    6
# Name: 1, dtype: int64)
# __________________
# (2, a    2
# b    5
# Name: 2, dtype: int64)
# __________________
# (3, a    1
# b    5
# Name: 3, dtype: int64)
# __________________

# %%
for i in df1:
    print(i)
# Out:
# a
# b

# %%
for i in df:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
# new_fare
# name_len
# fare1
# fare_info

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
# column wise iteration
for i in df1.items():
    print(i)
    print('________________________')
# Out:
# ('a', 0    2
# 1    3
# 2    2
# 3    1
# Name: a, dtype: int64)
# ________________________
# ('b', 0    5
# 1    6
# 2    5
# 3    5
# Name: b, dtype: int64)
# ________________________

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for i in df.items():
    print(i)
    print("___________________________")
# Out:
# ('PassengerId', 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64)
# ___________________________
# ('Survived', 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64)
# ___________________________
# ('Pclass', 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64)
# ___________________________
# ('Name', 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# ...

# %%
for i in df.iterrows():
    print(i)
    print("____________________________")
# Out:
# (0, PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# new_fare                         652.5
# name_len                            23
# fare1                            652.5
# fare_info                        cheap
# Name: 0, dtype: object)
# ____________________________
# (1, PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# ...

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
df1.apply(sum, axis=0)
# Out:
# a     8
# b    21
# dtype: int64

# %%
df1.apply(sum, axis=1)
# Out:
# 0    7
# 1    9
# 2    7
# 3    6
# dtype: int64

# %%
df1.applymap(lambda x:x**2)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2052\231730792.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(lambda x:x**2)
#    a   b
# 0  4  25
# 1  9  36
# 2  4  25
# 3  1  25

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
df1.sort_values(by='a')
# Out:
#    a  b
# 3  1  5
# 0  2  5
# 2  2  5
# 1  3  6

# %%
df1
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
df1 = df1.sort_values(by='b')

# %%
df1
# Out:
#    a  b
# 0  2  5
# 2  2  5
# 3  1  5
# 1  3  6

# %%
df1.sort_index()
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  2  5
# 3  1  5

# %%
df.sort_values(by="Fare").head(30)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 271          272         1       3      Tornquist, Mr. William Henry    male
# 597          598         0       3               Johnson, Mr. Alfred    male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr    male
# 633          634         0       1     Parr, Mr. William Henry Marsh    male
# 277          278         0       2       Parkes, Mr. Francis "Frank"    male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming    male
# 674          675         0       2        Watson, Mr. Ennis Hastings    male
# 263          264         0       1             Harrison, Mr. William    male
# 466          467         0       2             Campbell, Mr. William    male
# 732          733         0       2              Knight, Mr. Robert J    male
# 179          180         0       3               Leonard, Mr. Lionel    male
# ...
