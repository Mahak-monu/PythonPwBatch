# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = [1,2,3,4,5]

# %%
np.mean(data)
# Out:
# 3.0

# %%
np.median(data)
# Out:
# 3.0

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.mean(df['tip'])
# Out:
# 2.99827868852459

# %%
np.mean(df['size'])
# Out:
# 2.569672131147541

# %%
np.median(df['tip'])
# Out:
# 2.9

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
import statistics as stats

# %%
stats.mode(df['size'])
# Out:
# 2

# %%
stats.mode(df['total_bill'])
# Out:
# 13.42

# %%
stats.mode(df['tip'])
# Out:
# 2.0

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
np.percentile(df['total_bill'], [0,25,50,75,100])
# Out:
# array([ 3.07  , 13.3475, 17.795 , 24.1275, 50.81  ])

# %%
sns.scatterplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.scatterplot(df['size'])
# Out:
# <Axes: ylabel='size'>

# %%
data = [1,2,3,2,5,4,20,14,30,85,90]

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
numeric_df = df.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
numeric_df = df.select_dtypes(include=[int, float])
numeric_df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
corr = numeric_df.corr()

# %%
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
numeric_df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
numeric_df.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.pairplot(df)

# %%
data = [2,3,3,4,5,6,7,8,9,10,10,11,12,13,15]

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data = [1,2,10,11,12,15,10,30,31,32]

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(df['total_bill'], kde=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11956\1005607836.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'], kde=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# normal diistribution

# %%
arr = np.random.normal(0.5,0.2,1000)

# %%
arr
# Out:
# array([ 5.00539376e-01,  3.14757635e-01,  7.57211908e-01,  8.27676094e-01,
#         6.94827895e-01,  5.05612223e-01,  3.86190385e-01,  6.48523578e-01,
#         4.21323582e-01,  2.09049122e-01,  4.44124558e-01,  4.02070245e-01,
#         3.28129468e-01,  2.07271091e-01,  5.68868928e-01,  6.04403787e-01,
#         6.25627433e-01,  8.00120815e-01,  4.85221715e-01,  8.36506025e-02,
#         2.39705604e-01, -4.15843973e-04,  5.54615803e-01,  4.16890615e-01,
#         5.40663700e-01,  7.86209850e-01,  6.48275116e-01,  5.52054071e-01,
#         1.70716826e-01,  2.46699621e-01,  3.18596106e-01,  6.49249499e-01,
#         1.12220044e-01,  7.49179496e-01,  3.80815743e-01,  9.19899239e-01,
#         5.80421831e-01,  5.63242599e-01,  7.22680092e-01,  6.69051225e-01,
#         3.07366958e-01,  4.62018692e-01,  6.35939894e-01,  4.46962680e-01,
#         5.13566753e-01,  4.74062124e-01,  6.77901423e-01,  8.03023460e-01,
# ...

# %%
np.mean(arr)
# Out:
# 0.4975433739655775

# %%
np.std(arr)
# Out:
# 0.19697886481087387

# %%
sns.histplot(arr)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(arr, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.distplot(arr, kde=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11956\113049299.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(arr, kde=True)
# <Axes: ylabel='Density'>

# %%
np.mean(arr)-np.std(arr)
# Out:
# 0.3005645091547037

# %%
np.mean(arr)
# Out:
# 0.4975433739655775

# %%
np.median(arr)
# Out:
# 0.5013459689747692

# %%
stats.mode(arr)
# Out:
# 0.500539376485744
